# %%
import pandas as pd
pd.read_csv()
df.head()
df['Age'].mean()
df['Salary'].median()
df['Score'].std()
df.isna().sum()
df['Age'].corr(df['Salary'])
df.loc[df.Age > 30]
df['Score'].max() - df['Score'].min()
df.groupby('Department')['Salary'].mean()
df.groupby(['Department', 'Job Title']).size()
df.grouby('Department')['Age'].max()
pd.crosstab(df['Department'], df['Job Title'])
pd.crosstab(df['Department'], df['Job Title'], values=df['Salary'], aggunc='mean')
